# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
import pandas as pd
import numpy as np
import pickle
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import cv2

# %%
from keras.models import load_model
model = load_model('bien_menos_cuchillo.h5')
# Out:
# Using TensorFlow backend.

# %%
class_names = ['cuchara','cuchillo','cuenco','hervidor','pelador','ruido','sarten','taza','tenedor','tostadora']

# %%
prueba1 = cv2.imread('../../INPUT/new_data/cuchara.jpg')
prueba1 = cv2.resize(prueba1,(64,64))
prueba1 = prueba1.astype('float32') / 255

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image

img = prueba1
pred = model.predict(np.expand_dims(img,axis=0))[0]
print(pred)
for obj in class_names:
    print(f'{obj}: {round(pred[class_names.index(obj)],2)}')
print(np.expand_dims(img,axis=0).shape)
plt.imshow(img);
# Out:
# [5.5076081e-01 4.4315568e-01 4.0898376e-04 3.2159724e-04 1.2170165e-03
#  3.3230396e-04 4.3043619e-04 4.2263122e-04 2.6294491e-03 3.2109770e-04]
# cuchara: 0.550000011920929
# cuchillo: 0.4399999976158142
# cuenco: 0.0
# hervidor: 0.0
# pelador: 0.0
# ruido: 0.0
# sarten: 0.0
# taza: 0.0
# tenedor: 0.0
# tostadora: 0.0
# (1, 64, 64, 3)

# %%
def predicciones(foto):
    img = foto
    pred = model.predict(np.expand_dims(img,axis=0))[0]
    print(pred)
    for obj in class_names:
        print(f'{obj}: {round(pred[class_names.index(obj)],2)}')
    print(np.expand_dims(img,axis=0).shape)
    plt.imshow(img);

# %%
foto = cv2.imread('../../INPUT/new_data/cuchillo.jpg')
foto = cv2.resize(foto,(64,64))
foto = foto.astype('float32') / 255
predicciones(foto)
# Out:
# [0.0122209  0.00857311 0.03962426 0.00654287 0.0062025  0.10997482
#  0.79630005 0.00728132 0.00421363 0.00906643]
# cuchara: 0.009999999776482582
# cuchillo: 0.009999999776482582
# cuenco: 0.03999999910593033
# hervidor: 0.009999999776482582
# pelador: 0.009999999776482582
# ruido: 0.10999999940395355
# sarten: 0.800000011920929
# taza: 0.009999999776482582
# tenedor: 0.0
# tostadora: 0.009999999776482582
# (1, 64, 64, 3)

# %%
foto = cv2.imread('../../INPUT/new_data/cuenco.jpg')
foto = cv2.resize(foto,(64,64))
foto = foto.astype('float32') / 255
predicciones(foto)
# Out:
# [2.2247015e-05 1.1574512e-05 9.9314934e-01 2.1339849e-05 2.0904936e-05
#  2.4887879e-05 6.7010797e-03 3.0109022e-05 4.8827947e-06 1.3657632e-05]
# cuchara: 0.0
# cuchillo: 0.0
# cuenco: 0.9900000095367432
# hervidor: 0.0
# pelador: 0.0
# ruido: 0.0
# sarten: 0.009999999776482582
# taza: 0.0
# tenedor: 0.0
# tostadora: 0.0
# (1, 64, 64, 3)

# %%
foto = cv2.imread('../../INPUT/new_data/pelador.jpg')
foto = cv2.resize(foto,(64,64))
foto = foto.astype('float32') / 255
predicciones(foto)
# Out:
# [2.3419545e-03 1.7146815e-03 2.5363797e-03 4.8110806e-04 9.8872668e-01
#  1.6917094e-03 5.6986971e-04 5.0363614e-04 7.3120050e-04 7.0274487e-04]
# cuchara: 0.0
# cuchillo: 0.0
# cuenco: 0.0
# hervidor: 0.0
# pelador: 0.9900000095367432
# ruido: 0.0
# sarten: 0.0
# taza: 0.0
# tenedor: 0.0
# tostadora: 0.0
# (1, 64, 64, 3)

# %%
foto = cv2.imread('../../INPUT/new_data/sarten.jpg')
foto = cv2.resize(foto,(64,64))
foto = foto.astype('float32') / 255
predicciones(foto)
# Out:
# [0.00504424 0.00390171 0.04828139 0.0027934  0.00345194 0.0037325
#  0.90501136 0.00396126 0.00159165 0.02223057]
# cuchara: 0.009999999776482582
# cuchillo: 0.0
# cuenco: 0.05000000074505806
# hervidor: 0.0
# pelador: 0.0
# ruido: 0.0
# sarten: 0.9100000262260437
# taza: 0.0
# tenedor: 0.0
# tostadora: 0.019999999552965164
# (1, 64, 64, 3)

# %%
foto = cv2.imread('../../INPUT/new_data/taza.jpg')
foto = cv2.resize(foto,(64,64))
foto = foto.astype('float32') / 255
predicciones(foto)
# Out:
# [2.03303309e-04 1.07988504e-04 2.02413197e-04 8.49119606e-05
#  5.24698771e-05 1.57535556e-04 1.59174553e-04 8.19880152e-05
#  4.81926618e-05 9.98901963e-01]
# cuchara: 0.0
# cuchillo: 0.0
# cuenco: 0.0
# hervidor: 0.0
# pelador: 0.0
# ruido: 0.0
# sarten: 0.0
# taza: 0.0
# tenedor: 0.0
# tostadora: 1.0
# (1, 64, 64, 3)

# %%
foto = cv2.imread('../../INPUT/new_data/cuchillo.png')
foto = cv2.resize(foto,(64,64))
foto = foto.astype('float32') / 255
predicciones(foto)
# Out:
# [5.6219906e-01 4.3517661e-01 1.5400542e-04 1.4354543e-04 3.2539599e-04
#  1.4186130e-04 1.9225279e-04 1.7746704e-04 1.3685430e-03 1.2131922e-04]
# cuchara: 0.5600000023841858
# cuchillo: 0.4399999976158142
# cuenco: 0.0
# hervidor: 0.0
# pelador: 0.0
# ruido: 0.0
# sarten: 0.0
# taza: 0.0
# tenedor: 0.0
# tostadora: 0.0
# (1, 64, 64, 3)

# %%
foto = cv2.imread('../../INPUT/new_data/cuchara2.jpg')
foto = cv2.resize(foto,(64,64))
foto = foto.astype('float32') / 255
predicciones(foto)
# Out:
# [6.7451119e-04 5.5295514e-04 6.8253238e-04 1.0879302e-04 9.9724102e-01
#  1.1944669e-04 1.3590067e-04 1.2919800e-04 2.0857714e-04 1.4698654e-04]
# cuchara: 0.0
# cuchillo: 0.0
# cuenco: 0.0
# hervidor: 0.0
# pelador: 1.0
# ruido: 0.0
# sarten: 0.0
# taza: 0.0
# tenedor: 0.0
# tostadora: 0.0
# (1, 64, 64, 3)

# %%
foto = cv2.imread('../../INPUT/new_data/cuenco3.jpeg')
foto = cv2.resize(foto,(64,64))
foto = foto.astype('float32') / 255
predicciones(foto)
# Out:
# [5.22778835e-04 6.56773010e-03 1.91129278e-04 1.02177088e-04
#  3.31876276e-04 1.69526509e-04 5.49003817e-05 1.24070371e-04
#  9.91820216e-01 1.15581024e-04]
# cuchara: 0.0
# cuchillo: 0.009999999776482582
# cuenco: 0.0
# hervidor: 0.0
# pelador: 0.0
# ruido: 0.0
# sarten: 0.0
# taza: 0.0
# tenedor: 0.9900000095367432
# tostadora: 0.0
# (1, 64, 64, 3)

# %%
foto = cv2.imread('../../INPUT/new_data/taza2.jpg')
foto = cv2.resize(foto,(64,64))
foto = foto.astype('float32') / 255
predicciones(foto)
# Out:
# [2.2455154e-04 1.2282919e-04 2.2356583e-04 9.3222414e-05 5.8487061e-05
#  1.7271086e-04 1.7362443e-04 9.0159039e-05 5.7864960e-05 9.9878293e-01]
# cuchara: 0.0
# cuchillo: 0.0
# cuenco: 0.0
# hervidor: 0.0
# pelador: 0.0
# ruido: 0.0
# sarten: 0.0
# taza: 0.0
# tenedor: 0.0
# tostadora: 1.0
# (1, 64, 64, 3)

# %%
# importing google_images_download module 
from google_images_download import google_images_download  
  
# creating object 
response = google_images_download.googleimagesdownload()  
  
search_queries = ['cuchara','cuchillo','cuenco','hervidor','pelador','taza','tenedor','tostadora','sarten'] 
  
  
def downloadimages(query): 
    # keywords is the search query 
    # format is the image file format 
    # limit is the number of images to be downloaded 
    # print urs is to print the image file url 
    # size is the image size which can 
    # be specified manually ("large, medium, icon") 
    # aspect ratio denotes the height width ratio 
    # of images to download. ("tall, square, wide, panoramic") 
    arguments = {"keywords": query, 
                 "format": "jpg", 
                 "limit":5, 
                 "print_urls":True, 
                 "size": "medium", 
                 "aspect_ratio": "panoramic"}
    try: 
        response.download(arguments) 
      
    # Handling File NotFound Error     
    except FileNotFoundError:  
        arguments = {"keywords": query, 
                     "format": "jpg", 
                     "limit":5, 
                     "print_urls":True,  
                     "size": "medium"}
                       
        # Providing arguments for the searched query 
        try: 
            # Downloading the photos based 
            # on the given arguments 
            response.download(arguments)  
        except: 
            pass
  
# Driver Code 
for query in search_queries: 
    downloadimages(query)  
    print()
# Out:
# Item no.: 1 --> Item name = cuchara
# Evaluating...
# Starting Download...
#
#
# Unfortunately all 5 could not be downloaded because some images were not downloadable. 0 is all we got for this search filter!
#
# Errors: 0
#
#
#
# Item no.: 1 --> Item name = cuchillo
# Evaluating...
# Starting Download...
#
#
# Unfortunately all 5 could not be downloaded because some images were not downloadable. 0 is all we got for this search filter!
#
# Errors: 0
#
#
#
# Item no.: 1 --> Item name = cuenco
# Evaluating...
# Starting Download...
#
#
# Unfortunately all 5 could not be downloaded because some images were not downloadable. 0 is all we got for this search filter!
#
# Errors: 0
#
#
#
# Item no.: 1 --> Item name = hervidor
# Evaluating...
# Starting Download...
#
#
# Unfortunately all 5 could not be downloaded because some images were not downloadable. 0 is all we got for this search filter!
#
# Errors: 0
#
#
#
# Item no.: 1 --> Item name = pelador
# Evaluating...
# Starting Download...
#
# ...
